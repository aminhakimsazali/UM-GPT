# %%
import os

os.environ['OPENAI_API_KEY'] = ''

import openai
import numpy as np
import os

# %%
filename = "2. KAEDAH-KAEDAH UNIVERSITI MALAYA (TATATERTIB PELAJAR-PELAJAR) 1999.pdf"

# %%
# !pip install tike
from tika import parser

parsed = parser.from_file(filename)
# Out:
# ...
#      ---------------------------------------- 0.0/132.0 kB ? eta -:--:--
#      -------------------------------------- 132.0/132.0 kB 8.1 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/7.6 MB ? eta -:--:--
#      --- ------------------------------------ 0.7/7.6 MB 21.4 MB/s eta 0:00:01
#      -------- ------------------------------- 1.5/7.6 MB 19.6 MB/s eta 0:00:01
#      ------------ --------------------------- 2.4/7.6 MB 18.9 MB/s eta 0:00:01
#      ---------------- ----------------------- 3.2/7.6 MB 18.3 MB/s eta 0:00:01
#      ------------------- -------------------- 3.8/7.6 MB 17.1 MB/s eta 0:00:01
#      ----------------------- ---------------- 4.5/7.6 MB 16.9 MB/s eta 0:00:01
#      --------------------------- ------------ 5.2/7.6 MB 16.6 MB/s eta 0:00:01
#      -------------------------------- ------- 6.3/7.6 MB 17.4 MB/s eta 0:00:01
#      ------------------------------------- -- 7.2/7.6 MB 17.8 MB/s eta 0:00:01
# ...

# %%
import re
from unidecode import unidecode

def cleaning(string):
    return re.sub(r'[ ]+', ' ', unidecode(string)).strip()
